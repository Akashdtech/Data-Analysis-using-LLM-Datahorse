# %%
# from langchain.chat_models import ChatOpenAI
# from langchain.agents import create_pandas_dataframe_agent
# import pandas as pd

# df = pd.read_csv('/content/StudentPerformanceFactors.csv')

# llm = ChatOpenAI(openai_api_key = secret_key, temperature=0, model_name='gpt-3.5-turbo')
# agent = create_pandas_dataframe_agent(llm, df, verbose=True)

# agent.run('List all the categorical columns')

# %%
# !pip install datahorse

# %%
import datahorse as dh

# %%
df = dh.read('/content/StudentPerformanceFactors.csv')
df
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
df.chat('Name all the columns')
# Out:
# <details>
#   <summary>Review Code</summary>
#   <pre>
#   import pandas as pd
#
# def process(df):
#     column_names = df.columns.tolist()
#     return column_names
#   </pre>
# </details>
#
#
# <style>
# details {
#   border: 1px solid #aaa;
#   border-radius: 4px;
#   padding: 0.5em 0.5em 0;
#   margin-top: 3px;
# }
#
# summary {
#   font-weight: bold;
#   margin: -0.5em -0.5em 0;
#   padding: 0.5em;
# }
#
# details[open] {
#   padding: 0.5em;
# }
#
# details[open] summary {
#   border-bottom: 1px solid #aaa;
#   margin-bottom: 0.5em;
# }
# </style>
# ['Hours_Studied',
#  'Attendance',
#  'Parental_Involvement',
#  'Access_to_Resources',
#  'Extracurricular_Activities',
#  'Sleep_Hours',
#  'Previous_Scores',
#  'Motivation_Level',
#  'Internet_Access',
#  'Tutoring_Sessions',
#  'Family_Income',
#  'Teacher_Quality',
#  'School_Type',
#  'Peer_Influence',
#  'Physical_Activity',
#  'Learning_Disabilities',
#  'Parental_Education_Level',
#  'Distance_from_Home',
#  'Gender',
# ...

# %%
df.chat('Name all the numeric columns')
# Out:
# <details>
#   <summary>Review Code</summary>
#   <pre>
#   import pandas as pd
#
# def process(df):
#     numeric_cols = df.select_dtypes(include=[int]).columns
#     return numeric_cols
#   </pre>
# </details>
#
#
# <style>
# details {
#   border: 1px solid #aaa;
#   border-radius: 4px;
#   padding: 0.5em 0.5em 0;
#   margin-top: 3px;
# }
#
# summary {
#   font-weight: bold;
#   margin: -0.5em -0.5em 0;
#   padding: 0.5em;
# }
#
# details[open] {
#   padding: 0.5em;
# }
#
# details[open] summary {
#   border-bottom: 1px solid #aaa;
#   margin-bottom: 0.5em;
# }
# </style>
# Index(['Hours_Studied', 'Attendance', 'Sleep_Hours', 'Previous_Scores',
#        'Tutoring_Sessions', 'Physical_Activity', 'Exam_Score'],
#       dtype='object')

# %%
df.chat('Name all the categorical columns')
# Out:
# <details>
#   <summary>Review Code</summary>
#   <pre>
#   import pandas as pd
#
# def process(df):
#     categorical_columns = df.select_dtypes(include=['object']).columns.tolist()
#     return categorical_columns
#   </pre>
# </details>
#
#
# <style>
# details {
#   border: 1px solid #aaa;
#   border-radius: 4px;
#   padding: 0.5em 0.5em 0;
#   margin-top: 3px;
# }
#
# summary {
#   font-weight: bold;
#   margin: -0.5em -0.5em 0;
#   padding: 0.5em;
# }
#
# details[open] {
#   padding: 0.5em;
# }
#
# details[open] summary {
#   border-bottom: 1px solid #aaa;
#   margin-bottom: 0.5em;
# }
# </style>
# ['Parental_Involvement',
#  'Access_to_Resources',
#  'Extracurricular_Activities',
#  'Motivation_Level',
#  'Internet_Access',
#  'Family_Income',
#  'Teacher_Quality',
#  'School_Type',
#  'Peer_Influence',
#  'Learning_Disabilities',
#  'Parental_Education_Level',
#  'Distance_from_Home',
#  'Gender']

# %%
df.chat('Display a Pairplot for the df')
# Out:
# <details>
#   <summary>Review Code</summary>
#   <pre>
#   import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# def process(df):
#     sns.pairplot(df)
#     plt.show()
#   </pre>
# </details>
#
#
# <style>
# details {
#   border: 1px solid #aaa;
#   border-radius: 4px;
#   padding: 0.5em 0.5em 0;
#   margin-top: 3px;
# }
#
# summary {
#   font-weight: bold;
#   margin: -0.5em -0.5em 0;
#   padding: 0.5em;
# }
#
# details[open] {
#   padding: 0.5em;
# }
#
# details[open] summary {
#   border-bottom: 1px solid #aaa;
#   margin-bottom: 0.5em;
# }
# </style>

# %%
df.chat('Display a Barplot for the df with Attendance being the X axis and Hours_Studied being the Y axis')
# Out:
# <details>
#   <summary>Review Code</summary>
#   <pre>
#   import pandas as pd
# import matplotlib.pyplot as plt
#
# def process(df):
#     plt.figure(figsize=(10, 6))
#     plt.bar(df['Attendance'], df['Hours_Studied'])
#     plt.xlabel('Attendance')
#     plt.ylabel('Hours Studied')
#     plt.title('Barplot of Attendance vs Hours Studied')
#     plt.show()
#   </pre>
# </details>
#
#
# <style>
# details {
#   border: 1px solid #aaa;
#   border-radius: 4px;
#   padding: 0.5em 0.5em 0;
#   margin-top: 3px;
# }
#
# summary {
#   font-weight: bold;
#   margin: -0.5em -0.5em 0;
#   padding: 0.5em;
# }
#
# details[open] {
#   padding: 0.5em;
# }
#
# details[open] summary {
#   border-bottom: 1px solid #aaa;
#   margin-bottom: 0.5em;
# }
# </style>

# %%
df.chat('Display a Scatter Plot with Hours_Studied on the x-axis and Marks on the y-axis')
# Out:
# <details>
#   <summary>Review Code</summary>
#   <pre>
#   import pandas as pd
# import matplotlib.pyplot as plt
#
# def process(df):
#     plt.scatter(df['Hours_Studied'], df['Exam_Score'])
#     plt.xlabel('Hours Studied')
#     plt.ylabel('Marks')
#     plt.title('Scatter Plot of Hours Studied vs Marks')
#     plt.show()
#   </pre>
# </details>
#
#
# <style>
# details {
#   border: 1px solid #aaa;
#   border-radius: 4px;
#   padding: 0.5em 0.5em 0;
#   margin-top: 3px;
# }
#
# summary {
#   font-weight: bold;
#   margin: -0.5em -0.5em 0;
#   padding: 0.5em;
# }
#
# details[open] {
#   padding: 0.5em;
# }
#
# details[open] summary {
#   border-bottom: 1px solid #aaa;
#   margin-bottom: 0.5em;
# }
# </style>

# %%
df.chat('Display a Histogram for the Marks column')
# Out:
# <details>
#   <summary>Review Code</summary>
#   <pre>
#   import matplotlib.pyplot as plt
# import pandas as pd
#
# def process(df):
#     plt.figure(figsize=(10,6))
#     df['Exam_Score'].hist(bins=20)
#     plt.title('Histogram of Exam Score')
#     plt.xlabel('Exam Score')
#     plt.ylabel('Frequency')
#     plt.show()
#   </pre>
# </details>
#
#
# <style>
# details {
#   border: 1px solid #aaa;
#   border-radius: 4px;
#   padding: 0.5em 0.5em 0;
#   margin-top: 3px;
# }
#
# summary {
#   font-weight: bold;
#   margin: -0.5em -0.5em 0;
#   padding: 0.5em;
# }
#
# details[open] {
#   padding: 0.5em;
# }
#
# details[open] summary {
#   border-bottom: 1px solid #aaa;
#   margin-bottom: 0.5em;
# }
# </style>

# %%
df.chat('Display a Box Plot for Marks, grouped by Gender')
# Out:
# <details>
#   <summary>Review Code</summary>
#   <pre>
#   import pandas as pd
# import matplotlib.pyplot as plt
#
# def process(df):
#     df.boxplot(column='Exam_Score', by='Gender')
#     plt.title('Box Plot for Exam Score by Gender')
#     plt.xlabel('Gender')
#     plt.ylabel('Exam Score')
#     plt.show()
#   </pre>
# </details>
#
#
# <style>
# details {
#   border: 1px solid #aaa;
#   border-radius: 4px;
#   padding: 0.5em 0.5em 0;
#   margin-top: 3px;
# }
#
# summary {
#   font-weight: bold;
#   margin: -0.5em -0.5em 0;
#   padding: 0.5em;
# }
#
# details[open] {
#   padding: 0.5em;
# }
#
# details[open] summary {
#   border-bottom: 1px solid #aaa;
#   margin-bottom: 0.5em;
# }
# </style>

# %%
df.chat('Display a Heatmap for the numeric columns')
# Out:
# <details>
#   <summary>Review Code</summary>
#   <pre>
#   import pandas as pd
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# def process(df):
#     # Select numeric columns
#     numeric_cols = df.select_dtypes(include=[int]).columns.tolist()
#
#     # Create a heatmap for the numeric columns
#     plt.figure(figsize=(10, 8))
#     sns.heatmap(df[numeric_cols].corr(), annot=True, cmap='coolwarm', square=True)
#     plt.title('Correlation Matrix of Numeric Columns')
#     plt.show()
#   </pre>
# </details>
#
#
# <style>
# details {
#   border: 1px solid #aaa;
#   border-radius: 4px;
#   padding: 0.5em 0.5em 0;
#   margin-top: 3px;
# }
#
# summary {
#   font-weight: bold;
#   margin: -0.5em -0.5em 0;
#   padding: 0.5em;
# }
#
# details[open] {
#   padding: 0.5em;
# }
#
# details[open] summary {
#   border-bottom: 1px solid #aaa;
#   margin-bottom: 0.5em;
# }
# </style>

# %%
df_scaled = df.chat('Apply Standard Scaling to all the numeric columns')
df_scaled
# Out:
# <details>
#   <summary>Review Code</summary>
#   <pre>
#   import pandas as pd
# from sklearn.preprocessing import StandardScaler
#
# def process(df):
#     numeric_cols = df.select_dtypes(include=['int64']).columns
#     scaler = StandardScaler()
#     df[numeric_cols] = scaler.fit_transform(df[numeric_cols])
#     return df
#   </pre>
# </details>
#
#
# <style>
# details {
#   border: 1px solid #aaa;
#   border-radius: 4px;
#   padding: 0.5em 0.5em 0;
#   margin-top: 3px;
# }
#
# summary {
#   font-weight: bold;
#   margin: -0.5em -0.5em 0;
#   padding: 0.5em;
# }
#
# details[open] {
#   padding: 0.5em;
# }
#
# details[open] summary {
#   border-bottom: 1px solid #aaa;
#   margin-bottom: 0.5em;
# }
# </style>
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0          0.504942    0.348375                  Low                High
# 1         -0.162822   -1.383736                  Low              Medium
# ...

# %%
df_encoded = df_scaled.chat('Convert all the categorical columns to numeric code')
df_encoded
# Out:
# <details>
#   <summary>Review Code</summary>
#   <pre>
#   import pandas as pd
# from sklearn.preprocessing import LabelEncoder
#
# def process(df):
#     le = LabelEncoder()
#     categorical_columns = df.select_dtypes(include=['object']).columns
#     for col in categorical_columns:
#         df[col] = le.fit_transform(df[col])
#     return df
#   </pre>
# </details>
#
#
# <style>
# details {
#   border: 1px solid #aaa;
#   border-radius: 4px;
#   padding: 0.5em 0.5em 0;
#   margin-top: 3px;
# }
#
# summary {
#   font-weight: bold;
#   margin: -0.5em -0.5em 0;
#   padding: 0.5em;
# }
#
# details[open] {
#   padding: 0.5em;
# }
#
# details[open] summary {
#   border-bottom: 1px solid #aaa;
#   margin-bottom: 0.5em;
# }
# </style>
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0          0.504942    0.348375                     1                    0
# 1         -0.162822   -1.383736                     1                    2
# ...
